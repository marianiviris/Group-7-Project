# %%
#testing a change for git pull command
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time
from census import Census
from us import states
import gmaps
from config import cenkey

# %%
#https://api.census.gov/data/2010/dec/sf1?get=H001001,NAME&for=state:*&key=[user key]
death_pd = pd.read_csv("Causes_of_Death.csv")
death_pd['Cause Name']= death_pd['Cause Name'].replace({'All causes': 'Other Causes'})
death_pd.head()
# Out:
#    Year                                     113 Cause Name      Cause Name  \
# 0  2012  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 1  2016  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 2  2013  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
# 3  2000  Intentional self-harm (suicide) (*U03,X60-X84,...         Suicide
# 4  2014  Nephritis, nephrotic syndrome and nephrosis (N...  Kidney disease
#
#                   State  Deaths  Age-adjusted Death Rate
# 0               Vermont      21                      2.6
# 1               Vermont      30                      3.7
# 2               Vermont      30                      3.8
# 3  District of Columbia      23                      3.8
# 4               Arizona     325                      4.1

# %%
death_pd = death_pd.sort_values(by=['Year','State'],ascending=True)
death_pd.head(100)
# Out:
#        Year                                     113 Cause Name  \
# 946    1999  Intentional self-harm (suicide) (*U03,X60-X84,...
# 2210   1999                          Alzheimer's disease (G30)
# 3322   1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 4370   1999                  Influenza and pneumonia (J09-J18)
# 4570   1999                        Diabetes mellitus (E10-E14)
# 6592   1999       Chronic lower respiratory diseases (J40-J47)
# 6873   1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 7459   1999                 Cerebrovascular diseases (I60-I69)
# 8960   1999                      Malignant neoplasms (C00-C97)
# 9342   1999        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 10276  1999                                         All Causes
# 779    1999                          Alzheimer's disease (G30)
# 1166   1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 1988   1999  Intentional self-harm (suicide) (*U03,X60-X84,...
# ...

# %%
by_state= death_pd[['State','Cause Name','Year','Deaths']]

grouped= by_state.groupby(['State', 'Cause Name'])

grouped.first()
# Out:
#                                        Year  Deaths
# State         Cause Name
# Alabama       Alzheimer's disease      1999     772
#               CLRD                     1999    2179
#               Cancer                   1999    9506
#               Diabetes                 1999    1341
#               Heart disease            1999   13419
#               Influenza and pneumonia  1999    1228
#               Kidney disease           1999     979
#               Other Causes             1999   44806
#               Stroke                   1999    3148
#               Suicide                  1999     555
#               Unintentional injuries   1999    2313
# Alaska        Alzheimer's disease      1999      24
#               CLRD                     1999     146
#               Cancer                   1999     633
#               Diabetes                 1999      67
#               Heart disease            1999     563
#               Influenza and pneumonia  1999      46
# ...

# %%
dtoll=[]


dtoll= (['deaths']).sum /

# %%
# bar chart for total death rate

# %%
# Line graph comparing by year

# %%
# Diseases mapped onto 50 states and DC

# %%
# Highest rate of disease in each state

# %%
# Map of top 3 diseases in each state

# %%
# Top 10 states with most deaths
